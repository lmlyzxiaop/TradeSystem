# %%
import tushare as ts
import numpy as np
import pandas as pd
import matplotlib

# %%
ts.get_hist_data('600848',start='2017-06-05',end='2017-08-21')
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# date
# 2017-08-21  22.60  22.88  22.71  22.14   88234.07          0.31      1.38
# 2017-08-18  21.75  22.98  22.40  21.51  152416.92          0.52      2.38
# 2017-08-17  21.80  22.05  21.88  21.65   57783.36         -0.01     -0.05
# 2017-08-16  21.37  22.07  21.89  21.35   69848.00          0.45      2.10
# 2017-08-15  21.52  21.68  21.44  21.34   40952.00         -0.06     -0.28
# 2017-08-14  21.10  21.56  21.50  20.93   43295.10          0.27      1.27
# 2017-08-11  21.85  22.09  21.23  21.10   86670.40         -0.82     -3.72
# 2017-08-10  21.45  22.20  22.05  21.36  103465.63          0.65      3.04
# 2017-08-09  21.62  21.62  21.40  21.23   54995.01         -0.26     -1.20
# 2017-08-08  21.62  21.80  21.66  21.49   49367.10         -0.03     -0.14
# 2017-08-07  21.60  21.97  21.69  21.49   41980.90          0.20      0.93
# 2017-08-04  22.10  22.27  21.49  21.44   88873.78         -0.79     -3.55
# ...

# %%
def stopTrade():
    #止损
    if (Loi == ):
    
    #止盈
    if (roi == ):
        
    #超过仓位
    if (cash > ):

# %%
def cashControl():
    #盈利加仓
    #盈利减仓
    
    #亏损加仓
    #亏损加仓
# Out:
# 0.16

# %%
# Main function
#动态保持最优化仓位

total = 100000
day = '2017-06-01'

while(True):
    if (stopTrade()):
        print ("Trade is over")
        break
    
    #to do
